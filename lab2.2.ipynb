# %%
import numpy as np
import matplotlib.pyplot as plt

def gaussian(x, mu, sigma):
    return (1 / (np.sqrt(2 * np.pi) * sigma)) * np.exp(-0.5 * np.power((x - mu) / sigma, 2))

x = np.linspace(-20, 20, 400)

mu = [-15, -10, 0, 0.5, 1, 1.5, 2, 2.5, 5, 10]
sigma = [5, 5, 5, 5, 5, 5, 5, 5, 10, 10]

plt.figure(figsize=(12, 8))
for i in range(len(mu)):
    y = gaussian(x, mu[i], sigma[i])
    plt.plot(x, y, label=f'Gaussian {i+1}')

plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gaussian Membership Functions')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_gaussian(x, y, x_label, y_label, title):
    plt.plot(x, y, label='gaussian')
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.legend()
    plt.show()

# gaussians x, gaussians y, gaussians z
x = np.linspace(-5, 5, 1000)
y = np.linspace(-5, 5, 1000)
z = np.linspace(-5, 5, 1000)

plot_gaussian(x, norm.pdf(x, 0, 1), 'x', 'f(x)', 'gaussian x')
plot_gaussian(y, norm.pdf(y, 0, 1), 'y', 'f(y)', 'gaussian y')
plot_gaussian(z, norm.pdf(z, 0, 1), 'z', 'f(z)', 'gaussian z')

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X, Y = np.meshgrid(x, y)
Z = norm.pdf(X, 0, 1) + norm.pdf(Y, 0, 1)3D Plotting
ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
#   Cell In[3], line 7
#     Z = norm.pdf(X, 0, 1) + norm.pdf(Y, 0, 1)3D Plotting
#                                              ^
# SyntaxError: invalid decimal literal

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Gaussian functions parameters
mu = [0, 0, 0]
sigma = [1, 1, 1]

# Range for the Gaussian functions
x = np.linspace(-10, 10, 1000)
y = np.linspace(-10, 10, 1000)
z = np.linspace(-10, 10, 1000)

# Calculate Gaussian functions values
gx = norm.pdf(x, mu[0], sigma[0])
gy = norm.pdf(y, mu[1], sigma[1])
gz = norm.pdf(z, mu[2], sigma[2])

# Plot Gaussian functions values
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

X, Y = np.meshgrid(x, y)
Z = np.outer(gx, gy) + gz

ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Gaussian functions parameters
mu = [0, 0, 0, 0, 0, 0]
sigma = [1, 1, 1, 1, 1, 1]

# Range for the Gaussian functions
x = np.linspace(-10, 10, 1000)
y = np.linspace(-10, 10, 1000)
z = np.linspace(-10, 10, 1000)

# Calculate Gaussian functions values
gx = norm.pdf(x, mu[0], sigma[0])
gy = norm.pdf(y, mu[1], sigma[1])
gz = norm.pdf(z, mu[2], sigma[2])
gxy = norm.pdf(x, mu[3], sigma[3]) * norm.pdf(y, mu[4], sigma[4])
gxyz = norm.pdf(x, mu[5], sigma[5]) * norm.pdf(y, mu[6], sigma[6]) * norm.pdf(z, mu[7], sigma[7])

# Plot Gaussian functions values
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

X, Y = np.meshgrid(x, y)
Z = np.outer(gx, gy) + np.outer(gz, gxy) + gxyz

ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 19
#      17 gz = norm.pdf(z, mu[2], sigma[2])
#      18 gxy = norm.pdf(x, mu[3], sigma[3]) * norm.pdf(y, mu[4], sigma[4])
# ---> 19 gxyz = norm.pdf(x, mu[5], sigma[5]) * norm.pdf(y, mu[6], sigma[6]) * norm.pdf(z, mu[7], sigma[7])
#      21 # Plot Gaussian functions values
#      22 fig = plt.figure(figsize=(12, 8))
#
# IndexError: list index out of range

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Gaussian functions parameters
mu = [0, 0, 0, 0, 0, 0]
sigma = [1, 1, 1, 1, 1, 1]

# Range for the Gaussian functions
x = np.linspace(-10, 10, 1000)
y = np.linspace(-10, 10, 1000)
z = np.linspace(-10, 10, 1000)

# Calculate Gaussian functions values
gx = norm.pdf(x, mu[0], sigma[0])
gy = norm.pdf(y, mu[1], sigma[1])
gz = norm.pdf(z, mu[2], sigma[2])
gxy = norm.pdf(x, mu[3], sigma[3]) * norm.pdf(y, mu[4], sigma[4])
gxyz = norm.pdf(x, mu[5], sigma[5]) * norm.pdf(y, mu[6], sigma[6]) * norm.pdf(z, mu[7], sigma[7])

# Plot Gaussian functions values
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

X, Y = np.meshgrid(x, y)
Z = np.outer(gx, gy) + np.outer(gz, gxy) + gxyz

ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 19
#      17 gz = norm.pdf(z, mu[2], sigma[2])
#      18 gxy = norm.pdf(x, mu[3], sigma[3]) * norm.pdf(y, mu[4], sigma[4])
# ---> 19 gxyz = norm.pdf(x, mu[5], sigma[5]) * norm.pdf(y, mu[6], sigma[6]) * norm.pdf(z, mu[7], sigma[7])
#      21 # Plot Gaussian functions values
#      22 fig = plt.figure(figsize=(12, 8))
#
# IndexError: list index out of range

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Gaussian functions parameters
mu = [0, 0, 0, 0, 0, 0]
sigma = [1, 1, 1, 1, 1, 1]

# Range for the Gaussian functions
x = np.linspace(-10, 10, 1000)
y = np.linspace(-10, 10, 1000)
z = np.linspace(-10, 10, 1000)

# Calculate Gaussian functions values
gx = norm.pdf(x, mu[0], sigma[0])
gy = norm.pdf(y, mu[1], sigma[1])
gz = norm.pdf(z, mu[2], sigma[2])
gxy = norm.pdf(x, mu[3], sigma[3]) * norm.pdf(y, mu[4], sigma[4])
gxyz = norm.pdf(x, mu[5], sigma[5]) * norm.pdf(y, mu[6], sigma[6]) * norm.pdf(z, mu[7], sigma[7])

# Plot Gaussian functions values
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(1111, projection='3d')
X, Y = np.meshgrid(x, y)
Z = np.outer(gx, gy) * np.outer(gz, gxy) * gxyz

ax.plot_surface(X, Y, Z, cmap='viridis')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 19
#      17 gz = norm.pdf(z, mu[2], sigma[2])
#      18 gxy = norm.pdf(x, mu[3], sigma[3]) * norm.pdf(y, mu[4], sigma[4])
# ---> 19 gxyz = norm.pdf(x, mu[5], sigma[5]) * norm.pdf(y, mu[6], sigma[6]) * norm.pdf(z, mu[7], sigma[7])
#      21 # Plot Gaussian functions values
#      22 fig = plt.figure(figsize=(12, 8))
#
# IndexError: list index out of range

# %%
lab2_gaussian.py
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz
from tabulate import tabulate
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
def get_y(x):
return np.sin(np.abs(x)) + np.cos(np.abs(x))
def get_z(x, y):
return x * np.sin(y)
# Get values
x_values = np.linspace(0, 20, 100)
# x_values = np.linspace(10, 12.5, 100)
y_values = get_y(x_values)
z_values = get_z(x_values, y_values)
# Plot function Y
plt.plot(x_values, y_values)
plt.title("Y function")
plt.show()
# Plot function Z
plt.plot(x_values, z_values)
plt.title("Z function")
plt.show()
# Numbers of membership functions for input and output
mf_num_input = 6
mf_num_output = 9
# Means
x_means = np.linspace(min(x_values), max(x_values), mf_num_input)
y_means = np.linspace(min(y_values), max(y_values), mf_num_input)
z_means = np.linspace(min(z_values), max(z_values), mf_num_output)
# Sigmas
x_sigma = (max(x_values) - min(x_values)) / mf_num_input / 2
y_sigma = (max(y_values) - min(y_values)) / mf_num_input / 2
z_sigma = (max(z_values) - min(z_values)) / mf_num_output / 2
# Gaussian fuzzy membership functions
x_mf_gaussian = [fuzz.gaussmf(x_values, x_means[i], x_sigma) for i in 
range(mf_num_input)]
y_mf_gaussian = [fuzz.gaussmf(np.linspace(min(y_values), max(y_values), 100), 
y_means[i], y_sigma) for i in range(mf_num_input)]
z_mf_gaussian = [fuzz.gaussmf(np.linspace(min(z_values), max(z_values), 100), 
z_means[i], z_sigma) for i in range(mf_num_output)]
# Plot gaussian fuzzy membership functions for X
for i in range(mf_num_input):
plt.plot(x_values, x_mf_gaussian[i])
plt.title("Gaussians for X")
plt.show()
# Plot gaussian fuzzy membership functions for Y
for i in range(mf_num_input):
plt.plot(np.linspace(min(y_values), max(y_values), 100), y_mf_gaussian[i])
plt.title("Gaussians for Y")
plt.show()
# Plot gaussian fuzzy membership functions for Z
for i in range(mf_num_output):
plt.plot(np.linspace(min(z_values), max(z_values), 100), z_mf_gaussian[i])
plt.title("Gaussians for Z")
plt.show()
# Get number of best function for value
def get_fun_num(value, means, sigma):
best_func_value = -float("inf")
best_index = -1
for index, mean in enumerate(means):
if fuzz.gaussmf(value, mean, sigma) > best_func_value:
best_func_value = fuzz.gaussmf(value, mean, sigma)
best_index = index
return best_index
# Table of values
print("Values' table:")
table = [["y\\x"] + [str(x) for x in x_means]]
for y_value in y_means:
row = [round(y_value, 2)]
for x in x_means:
z = get_z(x, y_value)
row.append(round(z, 2))
table.append(row)
print(tabulate(table, tablefmt="grid"))
# Table of function's name
rules = {}
print("Function's name's table:")
table = [["y\\x"] + ["mx" + str(i) for i in range(1, mf_num_input + 1)]]
for i in range(mf_num_input):
row = ["my" + str(i + 1)]
for j in range(mf_num_input):
z = get_z(x_means[j], y_means[i])
best_func = get_fun_num(z, z_means, z_sigma)
row.append("mf" + str(best_func + 1))
rules[(j, i)] = best_func
table.append(row)
print(tabulate(table, tablefmt="grid"))
# Print rules
print("\nRules:")
for rule in rules.keys():
print(f"if (x is mx{rule[0] + 1}) and (y is my{rule[1] + 1}) then (z is 
mf{rules[rule] + 1})")
# Model
z_output = []
for x in x_values:
best_x_func = get_fun_num(x, x_means, x_sigma)
best_y_func = get_fun_num(get_y(x), y_means, y_sigma)
best_z_func = rules[(best_x_func, best_y_func)]
z_output.append(z_means[best_z_func])
# Plot results
plt.plot(x_values, z_output, label="Model")
plt.plot(x_values, z_values, label="True")
plt.title("True func and model func")
plt.legend()
plt.show()
# Get scores
mse = mean_squared_error(z_values, z_output)
mae = mean_absolute_error(z_values, z_output)
print(f"\nMean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
lab2_triangle.py
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz
from tabulate import tabulate
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
def get_y(x):
return np.sin(np.abs(x)) + np.cos(np.abs(x))
def get_z(x, y):
return x * np.sin(y)
# Get values
x_values = np.linspace(0, 20, 100)
# x_values = np.linspace(10, 12.5, 100)
y_values = get_y(x_values)
z_values = get_z(x_values, y_values)
# Plot function Y
plt.plot(x_values, y_values)
plt.title("Y function")
plt.show()
# Plot function Z
plt.plot(x_values, z_values)
plt.title("Z function")
plt.show()
# Numbers of membership functions for input and output
mf_num_input = 6
mf_num_output = 9
# Means
x_means = np.linspace(min(x_values), max(x_values), mf_num_input)
y_means = np.linspace(min(y_values), max(y_values), mf_num_input)
z_means = np.linspace(min(z_values), max(z_values), mf_num_output)
# Triangle fuzzy membership functions
x_mf_triangle = [fuzz.trimf(x_values, [x_means[i] - 3, x_means[i], x_means[i] + 3]) for 
i in range(mf_num_input)]
y_mf_triangle = [fuzz.trimf(np.linspace(min(y_values), max(y_values), 100), 
[y_means[i] - 0.5, y_means[i], y_means[i] + 0.5]) for i in range( mf_num_input)]
z_mf_triangle = [fuzz.trimf(np.linspace(min(z_values), max(z_values), 100), 
[z_means[i] - 4, z_means[i], z_means[i] + 4]) for i in range( mf_num_output)]
# Plot triangle fuzzy membership functions for X
for i in range(mf_num_input):
plt.plot(x_values, x_mf_triangle[i])
plt.title("Triangles for X")
plt.show()
# Plot triangle fuzzy membership functions for Y
for i in range(mf_num_input):
plt.plot(np.linspace(min(y_values), max(y_values), 100), y_mf_triangle[i])
plt.title("Triangles for Y")
plt.show()
# Plot triangle fuzzy membership functions for Z
for i in range(mf_num_output):
plt.plot(np.linspace(min(z_values), max(z_values), 100), z_mf_triangle[i])
plt.title("Triangles for Z")
plt.show()
# Calculate value for triangular mf
def calculate_trimf(x, a, b, c):
if a <= x < b:
return (x - a) / (b - a)
elif b <= x <= c:
return (c - x) / (c - b)
otherwise:
return 0.0
# Get number of best function for value
def get_fun_num(value, means, diff):
best_func_value = -float("inf")
best_index = -1
for index, mean in enumerate(means):
if calculate_trimf(value, mean - diff, mean, mean + diff) > best_func_value:
best_func_value = calculate_trimf(value, mean - diff, mean, mean + diff)
best_index = index
return best_index
# Table of values
print("Values' table:")
table = [["y\\x"] + [str(x) for x in x_means]]
for y_value in y_means:
row = [round(y_value, 2)]
for x in x_means:
z = get_z(x, y_value)
row.append(round(z, 2))
table.append(row)
print(tabulate(table, tablefmt="grid"))
# Table of function's name
rules = {}
print("Function's name's table:")
table = [["y\\x"] + ["mx" + str(i) for i in range(1, mf_num_input + 1)]]
for i in range(mf_num_input):
row = ["my" + str(i + 1)]
for j in range(mf_num_input):
z = get_z(x_means[j], y_means[i])
best_func = get_fun_num(z, z_means, 4)
row.append("mf" + str(best_func + 1))
rules[(j, i)] = best_func
table.append(row)
print(tabulate(table, tablefmt="grid"))
# Print rules
print("\nRules:")
for rules in rules:
print(f"if (x is mx{rule[0] + 1}) and (y is my{rule[1] + 1}) then (z is 
mf{rules[rule] + 1})")
# Model
z_output = []
for x in x_values:
best_x_func = get_fun_num(x, x_means, 3)
best_y_func = get_fun_num(get_y(x), y_means, 0.5)
best_z_func = rules[(best_x_func, best_y_func)]
z_output.append(z_means[best_z_func])
# Plot results
plt.plot(x_values, z_output, label="Model")
plt.plot(x_values, z_values, label="True")
plt.title("True func and model func")
plt.legend()
plt.show()
# Get scores
mse = mean_squared_error(z_values, z_output)
mae = mean_absolute_error(z_values, z_output)
print(f"\nMean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
# Out:
#   Cell In[8], line 92
#     print(f"if (x is mx{rule[0] + 1}) and (y is my{rule[1] + 1}) then (z is
#           ^
# SyntaxError: unterminated string literal (detected at line 92)
